# %% [markdown]
# ### HW 4: Build and evaluate regression models
# ## Taylor Martin CS:477 Python For Machine Learning

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_california_housing.html#sklearn.datasets.fetch_california_housing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing

# %%
from sklearn.metrics import mean_squared_error as mse, r2_score as r_2

# Follow this link to find more metrics for regression:
# https://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics
def regression_metrics(y_train, y_train_pred, y_test, y_test_pred):
    '''report the mse and r2 scores for both the training and test sets
    '''
    print('MSE Train: ', round(mse(y_train, y_train_pred), 3))
    print('MSE Test: ', round(mse(y_test, y_test_pred), 3))
    print('R^2 Train: ', round(r_2(y_train, y_train_pred), 3))
    print('R^2 Test: ', round(r_2(y_test, y_test_pred), 3))

# %% [markdown]
# #### Load the dataset

# %%
#Load the California housing dataset
ds = fetch_california_housing()
X = ds.data
y = ds.target
print('dataset size:', X.shape, y.shape)
print('Data in ds', dir(ds))
print(ds.DESCR)
# Out:
# dataset size: (20640, 8) (20640,)
# Data in ds ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
# data split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print('training set size:', X_train.shape[0])
print('test set size:', X_test.shape[0])
# Out:
# training set size: 14448
# test set size: 6192

# %% [markdown]
# #### 1 Train and evaluate a linear regression model using OLS. 20 points.
#     1) Train a linear reguression model
#     2) Evalate the model and print out the RMS and $R^2$ values on the training and test sets
#     3) What issues can you observe from the results? any possible solutions ?

# %%
#OLS: ordinary least squares. 
from sklearn.linear_model import LinearRegression as LR

#1) train. 5 points
LR = LR()
LR.fit(X_train, y_train)

#2) evaluate. 5 points 
y_train_pred = LR.predict(X_train)
y_test_pred = LR.predict(X_test)

#3) report the mse and r2 scores for both the training and test sets. 
regression_metrics(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# MSE Train:  0.517
# MSE Test:  0.543
# R^2 Train:  0.611
# R^2 Test:  0.593

# %% [markdown]
# #### 2 Train and evaluate the decision tree approach? 50 points.
#
#     1) Train a decision tree model. Please tune the arguments, 'criterion', 'max_depth', and 'min_samples_leaf', to achieve good performance
#     2) Print out the depth of the tree, the number of leaves, and the importance of each feature
#     3) Evalate the model and print out the RMS and  𝑅2  values on the training and test sets
#     4) Show the tree using tree.export_text() in sklearn
#     5) Print out the decision path for data sample X_test[0]
#     6) Test different max_depth values and analyse the results?

# %%
# Decision tree
from sklearn.tree import DecisionTreeRegressor as DTR

#1) train. 10 points
DTR = DTR()
DTR.fit(X_train, y_train)

#2) pirnt out tree attributes: the depth of the tree, 
#the number of leaves, and the importance of each feature. 10 points
print('Depth of the tree: ', DTR.get_depth())
print('Number of leaves: ', DTR.get_n_leaves())
print('Importance of each feature: ', DTR.feature_importances_)

#3) evaluate. 5 points
DTR_y_train_pred = DTR.predict(X_train)
DTR_y_test_pred = DTR.predict(X_test)
regression_metrics(y_train, DTR_y_train_pred, y_test, DTR_y_test_pred)
# Out:
# Depth of the tree:  37
# Number of leaves:  13878
# Importance of each feature:  [0.5269885  0.05166638 0.05182187 0.02754568 0.02801259 0.13695501
#  0.08703007 0.08997989]
# MSE Train:  0.0
# MSE Test:  0.546
# R^2 Train:  1.0
# R^2 Test:  0.591

# %%
#4) explore the trained decision tree using export_text(). 5 points
from sklearn import tree
tree.export_text(DTR)
# Out:
# '|--- feature_0 <= 5.03\n|   |--- feature_0 <= 3.07\n|   |   |--- feature_2 <= 4.22\n|   |   |   |--- feature_5 <= 2.50\n|   |   |   |   |--- feature_0 <= 2.19\n|   |   |   |   |   |--- feature_2 <= 3.33\n|   |   |   |   |   |   |--- feature_4 <= 1208.00\n|   |   |   |   |   |   |   |--- feature_6 <= 37.51\n|   |   |   |   |   |   |   |   |--- feature_6 <= 34.01\n|   |   |   |   |   |   |   |   |   |--- feature_7 <= -115.87\n|   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.51\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.51\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7\n|   |   |   |   |   |   |   |   |   |--- feature_7 >  -115.87\n|   |   |   |   |   |   |   |   |   |   |--- value: [0.25]\n|   |   |   |   |   |   |   |   |--- feature_6 >  34.01\n|   |   |   |   |   |   |   |   |   |--- feature_6 <= 34.02\n|   |   |   |   |   |   |   |   |   |   |--- value: [4.50]\n|   |   |   |   |   |   |   |   |   |--- feature_6 >  34.02\n|   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.43\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8\n|   |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.43\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3\n|   |   |   |   |   |   |   |--- feature_6 >  37.51\n|   |   |   |   |   |   |   |   |--- feature_7 <= -124.08\n|   |   |   |   |   |   |   |   |   |--- feature_2 <= 2.99\n|   |   |   |   |   |   |   |   |   |   |--- value: [0.60]\n|   |   |   |   |   |   |   |   |   |--- feature_2 >  2.99\n|   |   |   |   |   |   |   |   |   |   |--- value: [0.88]\n|   |   |   |   |   |   |   |   |--- feature_7 >  -124.08\n|   |   |   |   |   |   |   |   |   |--- feature_4 <= 45.00\n|   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.72\n|   |   |   |   |   |   |   |   |   |   |   |--- value: [0.68]\n|   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.72\n|   |   |   |   |   |   |   |   |   |   |   |--- value: [0.88]\n|   |   |   |   |   |   |   |   |   |--- feature_4 >  45.00\n|   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1.84\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9\n|   |   |   |   |   |   |   |   |   |   |--- feature_0 >  1.84\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3\n|   |   |   |   |   |   |--- feature_4 >  1208.00\n|   |   |   |   |   |   |   |--- feature_3 <= 1.14\n|   |   |   |   |   |   |   |   |--- feature_0 <= 2.04\n|   |   |   |   |   |   |   |   |   |--- feature_1 <= 35.50\n|   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 27.00\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6\n|   |   |   |   |   |   |   |   |   |   |--- feature_1 >  27.00\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4\n|   |   |   |   |   |   |   |   |   |--- feature_1 >  35.50\n|   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 35.94\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2\n|   |   |   |   |   |   |   |   |   |   |--- feature_6 >  35.94\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3\n|   |   |   |   |   |   |   |   |--- feature_0 >  2.04\n|   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.78\n|   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2.12\n|   |   |   |   |   |   |   |   |   |   |   |--- value: [4.58]\n|   |   |   |   |   |   |   |   |   |   |--- feature_0 >  2.12\n|   |   |   |   |   |   |   |   |   |   |   |--- value: [4.03]\n|   |   |   |   |   |   |   |   |   |--- feature_5 >  1.78\n|   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.19\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2\n|   |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.19\n|   |   |   |   |   |   |   |   |   |   |   |--- value: [4.10]\n|   |   |   | ...

# %%
#5) print out the decision path for the first test data sample X_test[0]. 5 points
print(X_test[0:1])
# Out:
# [[ 4.15180000e+00  2.20000000e+01  5.66307278e+00  1.07547170e+00
#    1.55100000e+03  4.18059299e+00  3.25800000e+01 -1.17050000e+02]]

# %%
##### 6) Question: Test different max_depth values (5, 8, 10, 20) and analyse the results? 15 points.
#  - SET criterion = 'mse' and min_samples_leaf = 20
from sklearn.tree import DecisionTreeRegressor as DTR

tree1 = DTR(max_depth = 5, criterion = 'friedman_mse', min_samples_leaf = 20)

#  - Compare the results with different max_depth values
tree1.fit(X_train, y_train)
tree1_y_train_pred = tree1.predict(X_train)
tree1_y_test_pred = tree1.predict(X_test)
regression_metrics(y_train, tree1_y_train_pred, y_test, tree1_y_test_pred)
# Out:
# MSE Train:  0.491
# MSE Test:  0.538
# R^2 Train:  0.631
# R^2 Test:  0.596

# %% [markdown]
# Summarize the main disadvantages decision trees
#
# Respone: A main disadvantage of a desicion tree is that they are largely unstable compared to other decision predictors. A minor change in the data can result in a major change in the structure of the decision tree. This will corrupt the data and give inaccurate results.

# %% [markdown]
# #### 3. Random forests. 30 points
#     1) What are the difference between bagging and random forests?
#     2)Train a random forest model. Please tune the arguments, n_estimators, max_features, max_depth, to achieve good performance.
#     3) Can your random forest model achieve better perofrmance than the decision tree? Please summarize the advantages of random forests?

# %% [markdown]
# ##### 1) What is the main problem of bagging approach? and how random forests can address the problem? 5 points
#
# Response: The main disadvantage of the bagging approach is that it may introduce a loss of interpretability of the model. The resulting model can experience significant bias.
# Random forests can help address this problem by randomly selecting subsets of features used in each data sample. This wil help with the iterpretability-accuracy tradeoff.

# %%
# Random forests
from sklearn.ensemble import RandomForestRegressor as RFR

# 2) train. 10 points
RFR = RFR()
RFR.fit(X_train, y_train)

#3) evaluate. 5 points. 10 extra points for R^2>0.8
RFR_y_train_pred = RFR.predict(X_train)
RFR_y_test_pred = RFR.predict(X_test)
regression_metrics(y_train, RFR_y_train_pred, y_test, RFR_y_test_pred)
# Out:
# MSE Train:  0.037
# MSE Test:  0.275
# R^2 Train:  0.973
# R^2 Test:  0.794

# %% [markdown]
# ##### 3) Can your random forest model achieve better perofrmance than the decision tree? Please summarize the advantages of random forests? 10 points
#
# Response: Yes, random forests are seen as a strong modeling technique and are far superior compared to a single decision tree.
#
# The main advantages of a random forest are:
#
# - It can perform both regression and classification tasks.
#
# - A random forest produces good predictions with ease of interpretability.
#
# - Random forests are efficient at hadling large datasets.
#
# - The random forest algorithm provides a higher level of accuracy in predicting outcomes over the decision tree algorithm.
